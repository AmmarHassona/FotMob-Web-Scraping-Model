# %%
import requests

# %%
import pandas as pd
from pandas import json_normalize

info_params = {
    'id': '1077894',
}

info_url = 'https://www.fotmob.com/api/playerData'

# Load data using json normalize
# The point of the method and extra code is to ensure that the data is loaded consistently every time
def load_player_info(url , params):
    with requests.Session() as session:
        try:
            # Get the player information
            response = session.get(info_url , params = params)
            response.raise_for_status()
            data = response.json()

            # Extract player information
            player_info = data.get('playerInformation' , {})
            info_df = json_normalize(player_info)

            # Extract player name
            player_name = data.get('name')
            return info_df , player_name  # Return both DataFrame and player name as a tuple
        except requests.exceptions.RequestException as e:
            print(f"Error loading data: {e}")
    return pd.DataFrame() , None  # Return empty DataFrame and None for player name if there's an error

# Call load_data method and drop all NaN values for columns that meet the threshold
info_df , player_name = load_player_info(info_url , info_params)
info_df = info_df.dropna(axis = 1 , thresh = len(info_df) * 0.9)

# Rename columns and drop translationKey column
info_df = info_df.rename(columns={'title' : 'Title' , 'value.fallback' : 'Info'})
info_df = info_df.drop(columns = ['translationKey'])

# Add player's name as a new row
info_df.loc[len(info_df)] = ['Name' , player_name]

file_name = f"{player_name.replace(' ', '_')}_Player_Info.csv"
info_df.to_csv(file_name , index = False , encoding = 'utf-8-sig')

info_df
# Out:
#             Title             Info
# 0          Height           186 cm
# 1           Shirt                5
# 2             Age               20
# 3  Preferred foot            Right
# 4         Country          England
# 5    Market value            €115M
# 6            Name  Jude Bellingham

# %%
# change url and params due to the data being in a different api
stats_params = {
    'playerId': '1077894',
    'seasonId': '2023/2024-87',
}

stats_url = 'https://www.fotmob.com/api/playerStats'

# repeat the method used to get the player data
def load_stats(url , params):
    with requests.Session() as session:
        try:
            response = session.get(url , params = params)
            response.raise_for_status()
            data = response.json()

            # since the data is nested multiple times, we will run a for loop to iterate over all of the nested keys
            player_stats = data.get('statsSection' , {}).get('items' , [])
            all_stats = []
            for item in player_stats:
                inner_key = item.get('items' , [])
                for item in inner_key:
                    all_stats.append(item)

            stats_df = json_normalize(all_stats)

            return stats_df
        except requests.exceptions.RequestException as e:
            print(f"Error loading data: {e}")
    return pd.DataFrame()

stats_df = load_stats(stats_url , stats_params)
stats_df = stats_df.rename(columns = {'title' : 'Title' , 'localizedTitleId' : 'Text' , 'statValue' : 'Stat' , 'per90' : 'statPer90' , 'percentileRank' : 'Percentile' , 'percentileRankPer90' : 'percentilePer90'})
stats_df = stats_df.drop(columns = ['statFormat'])

file_name = f"{player_name.replace(' ', '_')}_Player_Stats.csv"
stats_df.to_csv(file_name , index = False , encoding = 'utf-8-sig')

stats_df
# Out:
#                         Title                           Text   Stat  \
# 0                       Goals                          goals     19
# 1                          xG                 expected_goals  11.12
# 2                        xGOT       expected_goals_on_target  13.65
# 3               Penalty goals                 goals_subtitle      1
# 4            xG excl. penalty                 non_penalty_xg  10.33
# 5                       Shots                          shots     63
# 6             Shots on target                  ShotsOnTarget     35
# 7                     Assists                        assists      6
# 8                          xA               expected_assists   4.31
# 9             Accurate passes              successful_passes   1347
# 10              Pass accuracy     successful_passes_accuracy   89.8
# 11        Accurate long balls            long_balls_accurate     50
# 12         Long ball accuracy  long_ball_succeeeded_accuracy   83.3
# 13            Chances created                chances_created     48
# 14         Successful crosses             crosses_succeeeded      4
# 15             Cross accuracy    crosses_succeeeded_accuracy   19.0
# 16                   Dribbles             dribbles_succeeded     50
# 17      Dribbles success rate           won_contest_subtitle   58.8
# 18                    Touches                        touches   2056
# 19  Touches in opposition box                touches_opp_box    149
# 20               Dispossessed                   dispossessed     40
# 21                  Fouls won                      fouls_won     72
# 22                Tackles won              tackles_succeeded     34
# 23              Tackles won %      tackles_succeeded_percent   81.0
# 24                  Duels won                       duel_won    188
# 25                Duels won %               duel_won_percent   54.8
# 26                Aerials won                    aerials_won     26
# 27              Aerials won %            aerials_won_percent   50.0
# 28              Interceptions                  interceptions     21
# 29    Blocked scoring attempt                   shot_blocked     14
# 30            Fouls committed                          fouls     32
# 31                 Recoveries                     recoveries    118
# 32   Possession won final 3rd    poss_won_att_3rd_team_title     29
# 33              Dribbled past                  dribbled_past     24
# 34               Yellow cards                   yellow_cards      5
# 35                  Red cards                      red_cards      1
#
#     statPer90  Percentile  percentilePer90
# 0    0.736117  100.000000        95.890411
# 1    0.430702  100.000000        89.041096
# 2    0.528660  100.000000        94.520548
# 3    0.038743   87.671233        90.410959
# 4    0.400157  100.000000        87.671233
# 5    2.440809   90.410959        69.863014
# 6    1.356005   97.260274        89.041096
# 7    0.232458   91.780822        80.821918
# 8    0.166835   84.931507        67.123288
# 9   52.186827  100.000000        97.260274
# 10  89.800000   94.520548        94.520548
# 11   1.937150   95.890411        86.301370
# 12  83.333333   93.150685        93.150685
# 13   1.859664   93.150685        71.232877
# 14   0.154972   35.616438        16.438356
# 15  19.047619   31.506849        31.506849
# 16   1.937150   89.041096        68.493151
# 17  58.823529   82.191781        82.191781
# 18  79.655618   97.260274        97.260274
# 19   5.772708   91.780822        84.931507
# 20   1.549720   15.068493        49.315068
# 21   2.789496   95.890411        87.671233
# 22   1.317262   94.520548        78.082192
# 23  80.952381   89.041096        89.041096
# 24   7.283685   93.150685        76.712329
# 25  54.810496   89.041096        89.041096
# 26   1.007318   90.410959        61.643836
# 27  50.000000   78.082192        78.082192
# 28   0.813603   90.410959        79.452055
# 29   0.542402   84.931507        52.054795
# 30   1.239776   89.041096        42.465753
# 31   4.571675   84.931507        46.575342
# 32   1.123547   95.890411        91.780822
# 33   0.929832   10.958904        49.315068
# 34   0.193715   10.958904        43.835616
# 35   0.038743    4.109589        13.698630

# %%
stats_params = {
    'playerId': '1077894',
    'seasonId': '2023/2024-87',
}

stats_url = 'https://www.fotmob.com/api/playerStats'

# repeat the method used to get the player data
def load_shotmap(url, params):
    with requests.Session() as session:
        try:
            response = session.get(url, params=params)
            response.raise_for_status()
            data = response.json()

            shotmap = data.get('shotmap' , {})
            shots_df = json_normalize(shotmap)

            return shots_df
        except requests.exceptions.RequestException as e:
            print(f"Error loading data: {e}")
    return pd.DataFrame()

shots_df = load_shotmap(stats_url, stats_params)
shots_df = shots_df.drop(columns = ['goalCrossedY' , 'goalCrossedZ' , 'homeTeamId' , 'homeScore' , 'awayTeamId' , 'id' , 'playerId' , 'playerName' , 'teamColor' , 'teamColorDark' , 'teamId'])
shots_df = shots_df.drop(columns = ['onGoalShot.zoomRatio' , 'minAdded' , 'awayScore'])
shots_df = shots_df.drop(columns = ['box'])
shots_df = shots_df.drop(columns = ['isSavedOffLine'])
shots_df = shots_df.drop(columns = ['matchId'])

shots_df = shots_df.rename(columns = {
    'eventType' : 'Type' ,
    'min' : 'Minute' ,
    'expectedGoals' : 'xG' ,
    'expectedGoalsOnTarget' : 'onTargetxG' ,
    'isFromInsideBox' : 'insideBox' ,
    'onGoalShot.x' : 'onGoalShotX' ,
    'onGoalShot.y' : 'onGoalShotY' ,
    'period' : 'Half'
})

file_name = f"{player_name.replace(' ', '_')}_Player_Shots.csv"
shots_df.to_csv(file_name , index = False , encoding = 'utf-8-sig')

shots_df
# Out:
#              Type           x          y  Minute  isBlocked  isOnTarget  \
# 0    AttemptSaved   80.232524  17.833631       8      False        True
# 1    AttemptSaved   77.079126  53.879745      40       True        True
# 2            Miss  100.448276  37.202500      46      False       False
# 3    AttemptSaved   86.997059  32.627500      49      False        True
# 4            Miss   94.385965  33.923750      13      False       False
# ..            ...         ...        ...     ...        ...         ...
# 176          Goal   97.473684  41.945937      45      False        True
# 177  AttemptSaved   94.385965  31.102500      45      False        True
# 178          Miss   98.342105  49.185478      57      False       False
# 179  AttemptSaved   85.601471  42.813125      68       True        True
# 180          Goal   97.763158  37.050000      69      False        True
#
#        blockedX   blockedY        xG  onTargetxG   shotType    situation  \
# 0    103.482759  32.246250  0.020178      0.1160  RightFoot  RegularPlay
# 1     89.500000  46.172739  0.026094         NaN  RightFoot     FreeKick
# 2           NaN        NaN  0.385608         NaN     Header   FromCorner
# 3    102.724138  34.000000  0.082023      0.0984  RightFoot  RegularPlay
# 4           NaN        NaN  0.081436         NaN     Header  RegularPlay
# ..          ...        ...       ...         ...        ...          ...
# 176         NaN        NaN  0.227535      0.3283   LeftFoot  RegularPlay
# 177   98.245614  32.322500  0.479242      0.7627  RightFoot  RegularPlay
# 178         NaN        NaN  0.053035         NaN   LeftFoot  RegularPlay
# 179   92.400000  39.460952  0.077345         NaN  RightFoot     FreeKick
# 180         NaN        NaN  0.074156      0.1488     Header   FromCorner
#
#            Half  isOwnGoal  insideBox homeTeamName awayTeamName  \
# 0     FirstHalf      False      False  Al Nassr FC   Al-Taawoun
# 1     FirstHalf      False      False  Al Nassr FC   Al-Taawoun
# 2    SecondHalf      False       True  Al Nassr FC   Al-Taawoun
# 3    SecondHalf      False      False  Al Nassr FC   Al-Taawoun
# 4     FirstHalf      False       True  Al Fateh FC  Al Nassr FC
# ..          ...        ...        ...          ...          ...
# 176   FirstHalf      False       True  Al Nassr FC   Al Ittihad
# 177   FirstHalf      False       True  Al Nassr FC   Al Ittihad
# 178  SecondHalf      False       True  Al Nassr FC   Al Ittihad
# 179  SecondHalf      False      False  Al Nassr FC   Al Ittihad
# 180  SecondHalf      False       True  Al Nassr FC   Al Ittihad
#
#                 matchDate  onGoalShotX  onGoalShotY
# 0    2023-08-18T18:00:00Z     0.495701     0.193651
# 1    2023-08-18T18:00:00Z     0.616733     0.322751
# 2    2023-08-18T18:00:00Z     0.096561     0.677249
# 3    2023-08-18T18:00:00Z     1.403439     0.064550
# 4    2023-08-25T18:00:00Z     1.062709     0.677249
# ..                    ...          ...          ...
# 176  2024-05-27T18:00:00Z     0.717593     0.032275
# 177  2024-05-27T18:00:00Z     0.737765     0.022083
# 178  2024-05-27T18:00:00Z     2.000000     0.006060
# 179  2024-05-27T18:00:00Z     1.342923     0.322751
# 180  2024-05-27T18:00:00Z     1.161376     0.236118
#
# [181 rows x 20 columns]
